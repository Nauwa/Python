# %% [markdown]
# <a href="https://colab.research.google.com/github/Nauwa/Python/blob/main/RR_LR.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Importing Packages**

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # **Creating the Data Frame for CSV input**

# %%
data = pd.read_csv('imdb_movie_data.csv')
data
# Out:
#                             movie    year certificate    genre.1     genre.2  \
# 0        Aguirre, der Zorn Gottes  (1972)          '-     Action   Adventure
# 1                     The General  (1926)          '-     Action   Adventure
# 2    Kakushi-toride no san-akunin  (1958)          '-     Action   Adventure
# 3           The Magnificent Seven  (1960)          '-     Action   Adventure
# 4                    Sherlock Jr.  (1924)          '-     Action      Comedy
# ..                            ...     ...         ...        ...         ...
# 995                       Memento  (2000)          UA    Mystery    Thriller
# 996        The Outlaw Josey Wales  (1976)          UA    Western          '-
# 997                  Sardar Udham  (2021)      UA 13+  Biography       Crime
# 998                Thirteen Lives  (2022)      UA 16+     Action   Adventure
# 999                Dil Chahta Hai  (2001)     Unrated     Comedy       Drama
#
# ...

# %% [markdown]
# # **Data Preprocessing**

# %%
data.replace("'-", np.nan, inplace = True)

# %%
data.dropna(inplace=True)

# %%
data['year'] = data['year'].str.replace(r'[()]',"")
# Out:
# <ipython-input-290-cc1d66ba1c4e>:1: FutureWarning:
#
# The default value of regex will change from True to False in a future version.

# %%
data['certificate'] = data['certificate'].str.replace(r'[()]',"")
data
# Out:
# <ipython-input-291-75df4fba48c8>:1: FutureWarning:
#
# The default value of regex will change from True to False in a future version.
#                                      movie  year certificate    genre.1  \
# 159        The Girl with the Dragon Tattoo  2011      Banned      Crime
# 160                               Hamilton  2020         12+  Biography
# 162                            The Pianist  2002          13  Biography
# 163                              Moneyball  2011          13  Biography
# 165                             The Others  2001          13     Horror
# ..                                     ...   ...         ...        ...
# 982  Eternal Sunshine of the Spotless Mind  2004          UA      Drama
# 983                                Gattaca  1997          UA      Drama
# 984                             Ex Machina  2014          UA      Drama
# 985                                Gravity  2013          UA      Drama
# ...

# %%
data['gross_earning'] = data['gross_earning'].str.replace(r'[M]',"")
data
# Out:
# <ipython-input-292-c209af8c6c21>:1: FutureWarning:
#
# The default value of regex will change from True to False in a future version.
#                                      movie  year certificate    genre.1  \
# 159        The Girl with the Dragon Tattoo  2011      Banned      Crime
# 160                               Hamilton  2020         12+  Biography
# 162                            The Pianist  2002          13  Biography
# 163                              Moneyball  2011          13  Biography
# 165                             The Others  2001          13     Horror
# ..                                     ...   ...         ...        ...
# 982  Eternal Sunshine of the Spotless Mind  2004          UA      Drama
# 983                                Gattaca  1997          UA      Drama
# 984                             Ex Machina  2014          UA      Drama
# 985                                Gravity  2013          UA      Drama
# ...

# %%
data['gross_earning'] = data['gross_earning'].str.replace(r'[$]',"")
data
# Out:
# <ipython-input-293-d7e4f035de8f>:1: FutureWarning:
#
# The default value of regex will change from True to False in a future version.
#                                      movie  year certificate    genre.1  \
# 159        The Girl with the Dragon Tattoo  2011      Banned      Crime
# 160                               Hamilton  2020         12+  Biography
# 162                            The Pianist  2002          13  Biography
# 163                              Moneyball  2011          13  Biography
# 165                             The Others  2001          13     Horror
# ..                                     ...   ...         ...        ...
# 982  Eternal Sunshine of the Spotless Mind  2004          UA      Drama
# 983                                Gattaca  1997          UA      Drama
# 984                             Ex Machina  2014          UA      Drama
# 985                                Gravity  2013          UA      Drama
# ...

# %%
data['gross_earning'] = data['gross_earning'].str.replace(r'[#]',"")
data
# Out:
# <ipython-input-294-d8d2cc306efa>:1: FutureWarning:
#
# The default value of regex will change from True to False in a future version.
#                                      movie  year certificate    genre.1  \
# 159        The Girl with the Dragon Tattoo  2011      Banned      Crime
# 160                               Hamilton  2020         12+  Biography
# 162                            The Pianist  2002          13  Biography
# 163                              Moneyball  2011          13  Biography
# 165                             The Others  2001          13     Horror
# ..                                     ...   ...         ...        ...
# 982  Eternal Sunshine of the Spotless Mind  2004          UA      Drama
# 983                                Gattaca  1997          UA      Drama
# 984                             Ex Machina  2014          UA      Drama
# 985                                Gravity  2013          UA      Drama
# ...

# %%
data['certificate'] = data['certificate'].str.replace(r'[+]',"")
data
# Out:
# <ipython-input-295-1c97679d2123>:1: FutureWarning:
#
# The default value of regex will change from True to False in a future version.
#                                      movie  year certificate    genre.1  \
# 159        The Girl with the Dragon Tattoo  2011      Banned      Crime
# 160                               Hamilton  2020          12  Biography
# 162                            The Pianist  2002          13  Biography
# 163                              Moneyball  2011          13  Biography
# 165                             The Others  2001          13     Horror
# ..                                     ...   ...         ...        ...
# 982  Eternal Sunshine of the Spotless Mind  2004          UA      Drama
# 983                                Gattaca  1997          UA      Drama
# 984                             Ex Machina  2014          UA      Drama
# 985                                Gravity  2013          UA      Drama
# ...

# %%
data.isnull().sum()
# Out:
# movie            0
# year             0
# certificate      0
# genre.1          0
# genre.2          0
# genre.3          0
# imdb_rating      0
# metascore        0
# time_minute      0
# vote             0
# gross_earning    0
# dtype: int64

# %%
data.dtypes
# Out:
# movie             object
# year              object
# certificate       object
# genre.1           object
# genre.2           object
# genre.3           object
# imdb_rating      float64
# metascore         object
# time_minute       object
# vote               int64
# gross_earning     object
# dtype: object

# %%
data.gross_earning = data.gross_earning.astype(float)

# %%
data.dtypes
# Out:
# movie             object
# year              object
# certificate       object
# genre.1           object
# genre.2           object
# genre.3           object
# imdb_rating      float64
# metascore         object
# time_minute       object
# vote               int64
# gross_earning    float64
# dtype: object

# %%
data['time_minute'] = data['time_minute'].str.replace(r'[ MIN]',"")
data
# Out:
# <ipython-input-300-57a0248ff8c3>:1: FutureWarning:
#
# The default value of regex will change from True to False in a future version.
#                                      movie  year certificate    genre.1  \
# 159        The Girl with the Dragon Tattoo  2011      Banned      Crime
# 160                               Hamilton  2020          12  Biography
# 162                            The Pianist  2002          13  Biography
# 163                              Moneyball  2011          13  Biography
# 165                             The Others  2001          13     Horror
# ..                                     ...   ...         ...        ...
# 982  Eternal Sunshine of the Spotless Mind  2004          UA      Drama
# 983                                Gattaca  1997          UA      Drama
# 984                             Ex Machina  2014          UA      Drama
# 985                                Gravity  2013          UA      Drama
# ...

# %%
data['time_minute'] = data['time_minute'].str.replace(r'[min]',"")
data
# Out:
# <ipython-input-301-16ffddef1fe4>:1: FutureWarning:
#
# The default value of regex will change from True to False in a future version.
#                                      movie  year certificate    genre.1  \
# 159        The Girl with the Dragon Tattoo  2011      Banned      Crime
# 160                               Hamilton  2020          12  Biography
# 162                            The Pianist  2002          13  Biography
# 163                              Moneyball  2011          13  Biography
# 165                             The Others  2001          13     Horror
# ..                                     ...   ...         ...        ...
# 982  Eternal Sunshine of the Spotless Mind  2004          UA      Drama
# 983                                Gattaca  1997          UA      Drama
# 984                             Ex Machina  2014          UA      Drama
# 985                                Gravity  2013          UA      Drama
# ...

# %%
data.dtypes
# Out:
# movie             object
# year              object
# certificate       object
# genre.1           object
# genre.2           object
# genre.3           object
# imdb_rating      float64
# metascore         object
# time_minute       object
# vote               int64
# gross_earning    float64
# dtype: object

# %%
data.time_minute = data.time_minute.astype(int)

# %%
data.dtypes
# Out:
# movie             object
# year              object
# certificate       object
# genre.1           object
# genre.2           object
# genre.3           object
# imdb_rating      float64
# metascore         object
# time_minute        int64
# vote               int64
# gross_earning    float64
# dtype: object

# %%
data.reset_index(inplace=True)

# %%
data
# Out:
#      index                                  movie  year certificate  \
# 0      159        The Girl with the Dragon Tattoo  2011      Banned
# 1      160                               Hamilton  2020          12
# 2      162                            The Pianist  2002          13
# 3      163                              Moneyball  2011          13
# 4      165                             The Others  2001          13
# ..     ...                                    ...   ...         ...
# 452    982  Eternal Sunshine of the Spotless Mind  2004          UA
# 453    983                                Gattaca  1997          UA
# 454    984                             Ex Machina  2014          UA
# 455    985                                Gravity  2013          UA
# 456    986                   The Butterfly Effect  2004          UA
#
#        genre.1   genre.2    genre.3  imdb_rating metascore  time_minute  \
# 0        Crime     Drama    Mystery          7.8        71          158
# ...

# %% [markdown]
# # **Descriptive** **Analysis**

# %%
data.shape
# Out:
# (457, 12)

# %%
data.columns
# Out:
# Index(['index', 'movie', 'year', 'certificate', 'genre.1', 'genre.2',
#        'genre.3', 'imdb_rating', 'metascore', 'time_minute', 'vote',
#        'gross_earning'],
#       dtype='object')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 457 entries, 0 to 456
# Data columns (total 12 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   index          457 non-null    int64
#  1   movie          457 non-null    object
#  2   year           457 non-null    object
#  3   certificate    457 non-null    object
#  4   genre.1        457 non-null    object
#  5   genre.2        457 non-null    object
#  6   genre.3        457 non-null    object
#  7   imdb_rating    457 non-null    float64
#  8   metascore      457 non-null    object
#  9   time_minute    457 non-null    int64
#  10  vote           457 non-null    int64
#  11  gross_earning  457 non-null    float64
# dtypes: float64(2), int64(3), object(7)
# memory usage: 43.0+ KB

# %%
data.describe()
# Out:
#             index  imdb_rating  time_minute          vote  gross_earning
# count  457.000000   457.000000   457.000000  4.570000e+02     457.000000
# mean   568.702407     7.936761   124.008753  4.190930e+05      95.420897
# std    235.444063     0.279655    27.301033  3.936737e+05     131.795479
# min    159.000000     7.600000    66.000000  2.644300e+04       0.000000
# 25%    374.000000     7.700000   103.000000  1.246740e+05       9.280000
# 50%    573.000000     7.900000   120.000000  2.950520e+05      45.300000
# 75%    796.000000     8.100000   139.000000  5.951440e+05     132.070000
# max    986.000000     9.000000   238.000000  2.687020e+06     936.660000

# %%
len(data['imdb_rating'].unique())
# Out:
# 14

# %%
data['genre.1'].value_counts()
# Out:
# Action       118
# Animation     68
# Drama         67
# Biography     59
# Crime         48
# Comedy        46
# Adventure     41
# Horror         5
# Mystery        2
# Fantasy        1
# Family         1
# Film-Noir      1
# Name: genre.1, dtype: int64

# %%
data['year'].value_counts()
# Out:
# 2014      20
# 2004      19
# 2007      16
# 2009      16
# 2001      15
#           ..
# 1954       1
# I 2019     1
# I 2008     1
# 1955       1
# I 1985     1
# Name: year, Length: 93, dtype: int64

# %%
data['year'] = data['year'].str.replace(r'[I ]',"")
# Out:
# <ipython-input-314-0d9ce4fea817>:1: FutureWarning:
#
# The default value of regex will change from True to False in a future version.

# %%
data['year'] = data['year'].str.replace(r'[I]',"")
# Out:
# <ipython-input-315-23ef712cbe14>:1: FutureWarning:
#
# The default value of regex will change from True to False in a future version.

# %%
data['year'].value_counts()
# Out:
# 2004    21
# 2014    20
# 2007    17
# 2009    16
# 2001    16
#         ..
# 1954     1
# 1961     1
# 1977     1
# 1931     1
# 1981     1
# Name: year, Length: 78, dtype: int64

# %% [markdown]
# # **Action Movie Analysis**

# %%
action_movie=data[data['genre.1']=='Action']

# %%
action_movie
# Out:
#      index                              movie  year certificate genre.1  \
# 13     194       Kingsman: The Secret Service  2014           A  Action
# 14     195  Everything Everywhere All at Once  2022           A  Action
# 15     197                       End of Watch  2012           A  Action
# 16     198                       The Revenant  2015           A  Action
# 17     199                         Apocalypto  2006           A  Action
# ..     ...                                ...   ...         ...     ...
# 397    871                     V for Vendetta  2005          UA  Action
# 398    872                            Warrior  2011          UA  Action
# 399    873              The Dark Knight Rises  2012          UA  Action
# 400    874                The Bourne Identity  2002          UA  Action
# 401    875               The Bourne Ultimatum  2007          UA  Action
#
#         genre.2    genre.3  imdb_rating metascore  time_minute     vote  \
# ...

# %%
action_movie.describe()
# Out:
#             index  imdb_rating  time_minute          vote  gross_earning
# count  118.000000   118.000000   118.000000  1.180000e+02     118.000000
# mean   582.949153     7.947458   130.500000  6.009761e+05     165.176356
# std    272.150249     0.319110    23.362528  4.924582e+05     192.248894
# min    194.000000     7.600000    81.000000  2.644300e+04       0.010000
# 25%    229.250000     7.700000   112.250000  2.295650e+05      35.637500
# 50%    673.000000     7.900000   129.500000  4.869530e+05      92.835000
# 75%    828.750000     8.100000   144.000000  7.665925e+05     232.635000
# max    875.000000     9.000000   201.000000  2.687020e+06     936.660000

# %%
import plotly.express as px

# %%
fig = px.box(action_movie, y='imdb_rating')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig = px.scatter(action_movie, x='year', y='gross_earning')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# **Group by**

# %%
new_df = action_movie[['year','genre.1','gross_earning']]
new_df = new_df.groupby(['year'], as_index=False).sum()
new_df
# Out:
#     year  gross_earning
# 0   1938           3.98
# 1   1959          13.28
# 2   1961         145.00
# 3   1962          39.10
# 4   1964          65.58
# 5   1967          45.30
# 6   1969          12.06
# 7   1971          51.53
# 8   1973          25.00
# 9   1974           2.49
# 10  1977         322.74
# 11  1980         347.71
# 12  1981          12.47
# 13  1982         158.99
# 14  1983         309.13
# 15  1984         238.63
# 16  1985           4.14
# 17  1986          85.16
# 18  1987         178.37
# 19  1992          75.51
# 20  1993         586.33
# 21  1994          19.50
# 22  1995         167.45
# 23  1997          63.54
# 24  1998          11.17
# 25  2000         315.79
# 26  2001         500.81
# 27  2002         704.39
# 28  2003         754.07
# 29  2004         338.58
# 30  2005         683.13
# 31  2006         299.20
# 32  2007         304.73
# 33  2008         998.27
# 34  2009        1241.40
# 35  2010         434.40
# 36  2011          17.77
# ...

# %%
fig = px.scatter(new_df, x='year', y='gross_earning')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
new_df2 = action_movie[['year', 'movie']]
new_df2 = new_df2.groupby(['year'], as_index=False).count()
new_df2.head(5)
# Out:
#    year  movie
# 0  1938      1
# 1  1959      1
# 2  1961      1
# 3  1962      1
# 4  1964      2

# %%
fig = px.scatter(new_df2, x='year', y='movie')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
data.year = data.year.astype(int)
bins = np.linspace(min(data['year']), max(data['year']), 8)
bins
# Out:
# array([1931., 1944., 1957., 1970., 1983., 1996., 2009., 2022.])

# %%
group_names = ['1', '2', '3','4','5','6','7']

# %%
data['year-binned'] = pd.cut(data['year'], bins, labels=group_names , include_lowest=True )
data[['year','year-binned']].head(5)
# Out:
#    year year-binned
# 0  2011           7
# 1  2020           7
# 2  2002           6
# 3  2011           7
# 4  2001           6

# %%
data["year-binned"].value_counts()
# Out:
# 6    167
# 7    133
# 5     71
# 4     37
# 3     29
# 2     13
# 1      7
# Name: year-binned, dtype: int64

# %%
import matplotlib as plt
from matplotlib import pyplot
pyplot.bar(group_names, data['year-binned'].value_counts())

plt.pyplot.xlabel("Year Bin")
plt.pyplot.ylabel("Movie Count")
plt.pyplot.title("Movie count in Year Bin")
# Out:
# Text(0.5, 1.0, 'Movie count in Year Bin')

# %%
# draw historgram of attribute "horsepower" with bins = 3
plt.pyplot.hist(data["year"], bins = 6)

# set x/y labels and plot title
plt.pyplot.xlabel("Year Bin")
plt.pyplot.ylabel("count")
plt.pyplot.title("Movie count in Year Bin")
# Out:
# Text(0.5, 1.0, 'Movie count in Year Bin')

# %% [markdown]
# # **Summary**
#
#
# * More movies have been released in recent years
# * In parallel, gross earnings have also been increased
# * The popular genre is "Adventure", followed by "Animation" and Drama

# %% [markdown]
# # **Linear Regression**

# %%
import numpy as np
from sklearn.linear_model import LinearRegression

# %%
x = data[['imdb_rating']]
y = data[['gross_earning']]

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.25)

# %%
model = LinearRegression().fit(x_train, y_train)

# %%
y_pred = model.predict(x_test)
y_pred
# Out:
# array([[157.22780429],
#        [ 63.47457429],
#        [ 84.3086254 ],
#        [105.14267651],
#        [ 63.47457429],
#        [115.55970207],
#        [ 63.47457429],
#        [105.14267651],
#        [ 94.72565096],
#        [ 94.72565096],
#        [157.22780429],
#        [ 84.3086254 ],
#        [ 63.47457429],
#        [105.14267651],
#        [ 73.89159984],
#        [115.55970207],
#        [146.81077873],
#        [105.14267651],
#        [105.14267651],
#        [157.22780429],
#        [ 73.89159984],
#        [105.14267651],
#        [115.55970207],
#        [136.39375318],
#        [ 73.89159984],
#        [ 63.47457429],
#        [ 94.72565096],
#        [ 84.3086254 ],
#        [ 63.47457429],
#        [146.81077873],
#        [ 73.89159984],
#        [188.47888096],
#        [ 73.89159984],
#        [ 84.3086254 ],
#        [157.22780429],
#        [105.14267651],
#        [125.97672762],
#        [ 73.89159984],
#        [ 84.3086254 ],
#        [125.97672762],
# ...

# %%
from sklearn.metrics import r2_score, mean_squared_error
print('R2 score',r2_score(y_test, y_pred))
print('Mean squared error', np.sqrt(mean_squared_error(y_test, y_pred)))
# Out:
# R2 score 0.005041110264973003
# Mean squared error 120.34869756133463

# %% [markdown]
# ## **Ridge Regression**

# %%
from sklearn.linear_model import Ridge
#R = Ridge(alpha=0.0001)
R = Ridge(alpha=0.1)

# %%
R.fit(x_train, y_train)
# Out:
# Ridge(alpha=0.1)

# %%
y_pred1 = R.predict(x_test)

# %%
print('R2 score',r2_score(y_test, y_pred1))
print('Mean squared error', np.sqrt(mean_squared_error(y_test, y_pred1)))
# Out:
# R2 score 0.005187323161907731
# Mean squared error 120.33985439283255

# %% [markdown]
# # **Grid Search**

# %%
from sklearn.model_selection import GridSearchCV
parameters1= [{'alpha': [0.001,0.1,1, 10, 100, 1000, 10000, 100000, 100000]}]
parameters1
# Out:
# [{'alpha': [0.001, 0.1, 1, 10, 100, 1000, 10000, 100000, 100000]}]

# %%
RR=Ridge()
RR
# Out:
# Ridge()

# %%
Grid1 = GridSearchCV(RR, parameters1,cv=4)

# %%
Grid1.fit(x,y)
# Out:
# GridSearchCV(cv=4, estimator=Ridge(),
#              param_grid=[{'alpha': [0.001, 0.1, 1, 10, 100, 1000, 10000, 100000,
#                                     100000]}])

# %%
BestRR = Grid1.best_estimator_
BestRR
# Out:
# Ridge(alpha=10)

# %%
BestRR.fit(x_train, y_train)
# Out:
# Ridge(alpha=10)

# %%
y_pred2 = BestRR.predict(x_test)
y_pred2
# Out:
# array([[141.38366637],
#        [ 73.03056997],
#        [ 88.22014695],
#        [103.40972393],
#        [ 73.03056997],
#        [111.00451241],
#        [ 73.03056997],
#        [103.40972393],
#        [ 95.81493544],
#        [ 95.81493544],
#        [141.38366637],
#        [ 88.22014695],
#        [ 73.03056997],
#        [103.40972393],
#        [ 80.62535846],
#        [111.00451241],
#        [133.78887788],
#        [103.40972393],
#        [103.40972393],
#        [141.38366637],
#        [ 80.62535846],
#        [103.40972393],
#        [111.00451241],
#        [126.19408939],
#        [ 80.62535846],
#        [ 73.03056997],
#        [ 95.81493544],
#        [ 88.22014695],
#        [ 73.03056997],
#        [133.78887788],
#        [ 80.62535846],
#        [164.16803183],
#        [ 80.62535846],
#        [ 88.22014695],
#        [141.38366637],
#        [103.40972393],
#        [118.5993009 ],
#        [ 80.62535846],
#        [ 88.22014695],
#        [118.5993009 ],
# ...

# %%
BestRR.score(x,y)
# Out:
# 0.03851745223980929

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
def DistributionPlot(RedFunction, BlueFunction, RedName, BlueName, Title):
    width = 12
    height = 10
    plt.figure(figsize=(width, height))

    #ax1 = sns.distplot(RedFunction, hist=False, color="r", label=RedName)
    #ax2 = sns.distplot(BlueFunction, hist=False, color="b", label=BlueName, ax=ax1)

    ax1 = sns.distplot(RedFunction, color="r", label=RedName)
    ax2 = sns.distplot(BlueFunction, color="b", label=BlueName, ax=ax1)

    plt.title(Title)
    plt.xlabel('Value of x')
    plt.ylabel('Value of y')

    plt.show()
    plt.close()

# %%
Title = 'Distribution  Plot of Linear Regression Predicted Value Using Training Data vs Training Data Distribution'
DistributionPlot(y_test, y_pred, "Actual Values (Train)", "Predicted Values (Train)", Title)
# Out:
# <ipython-input-358-c0ec611fcaa1>:9: UserWarning:
#
#
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#
# <ipython-input-358-c0ec611fcaa1>:10: UserWarning:
#
#
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751

# %%
Title = 'Distribution  Plot of Ridge Regression Predicted Value Using Training Data vs Training Data Distribution'
DistributionPlot(y_test, y_pred1, "Actual Values (Train)", "Predicted Values (Train)", Title)
# Out:
# <ipython-input-358-c0ec611fcaa1>:9: UserWarning:
#
#
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#
# <ipython-input-358-c0ec611fcaa1>:10: UserWarning:
#
#
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751

# %%
Title = 'Distribution  Plot of Best Ridge Regression Predicted Value Using Training Data vs Training Data Distribution'
DistributionPlot(y_test, y_pred2, "Actual Values (Train)", "Predicted Values (Train)", Title)
# Out:
# <ipython-input-358-c0ec611fcaa1>:9: UserWarning:
#
#
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#
# <ipython-input-358-c0ec611fcaa1>:10: UserWarning:
#
#
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
